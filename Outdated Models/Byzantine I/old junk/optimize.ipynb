# %%
import os
if os.getcwd()!="/Users/gabthesav/Desktop/Pyfiles/Artificial Inteligence/Machine Learning/Byzantine I":
    os.chdir("/Users/gabthesav/Desktop/Pyfiles/Artificial Inteligence/Machine Learning/Byzantine I")
print(os.getcwd())
# Out:
# /Users/gabthesav/Desktop/Pyfiles/Artificial Inteligence/Machine Learning/Space invaders New

# %%
from tuners.tuner import tuner_for_bob, get_remaining_ram_in_gb
import json

print(get_remaining_ram_in_gb())
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2025-04-11 23:01:19.491918: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.7053146362304688

# %%
try:
    tuner = tuner_for_bob(maximum_capacity=1)#oops this will not leave space for data. Fix that!!!

    #tuner.fill_up(gigabytes_reserved=0.5) #Add better verbosity mode!!!

    tuner.add_render(**tuner.get_random_hyperparameters())

    assert tuner.sessions!=[]

    data = tuner.tune(action_steps=30, killers=3, killer_ratio=0.5, testing_steps=100)

    filename = "optimum.json"
    with open(filename, 'w') as json_file:
        json.dump(data, json_file, indent=4)  # indent for pretty printing

    print(f"Data has been written to {filename}")
except Exception as e:
    print(e)
# Out:
# {'alpha': 0.7, 'epsilon_init': 1.0, 'epsilon_decay': 0.999, 'epsilon_min': 0.01, 'gamma': 0.995, 'layer1_size': 1024, 'layer2_size': 512, 'layer3_size': 256, 'layer4_size': 128, 'batch_size': 16, 'learning_rate': 0.0001, 'dropout1': 0.3, 'dropout2': 0.3, 'dropout3': 0.3, 'reg1': 0.01, 'reg2': 0.1, 'reg3': 0.0, 'memory': 10000, 'input_shape': (1, 23), 'actions': 4, 'sample_size_for_TDERR': 200, 'time_step_threshold': 100}
# Step 1/10.0 killer 0/3
# Step 2/10.0 killer 0/3
# Step 3/10.0 killer 0/3
# Step 4/10.0 killer 0/3
# Step 5/10.0 killer 0/3
# Step 6/10.0 killer 0/3
# Step 7/10.0 killer 0/3
# Step 8/10.0 killer 0/3
# Step 9/10.0 killer 0/3
# Step 10/10.0 killer 0/3
# Pruning 1 instances!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/gabthesav/Desktop/Pyfiles/Artificial Inteligence/Machine Learning/Space invaders New/optimize.ipynb Cell 3 line 1
# ...
